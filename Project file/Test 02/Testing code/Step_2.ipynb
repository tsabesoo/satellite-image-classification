# %%
from PIL import Image, ImageDraw
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import load_model
import pickle

# Load the model
model_save_path = r"C:\\Users\\thath\\OneDrive - University of Bradford\\Discipline-specific Artificial Intelligence Project\\Project file\\Test 02\\model.keras"
model = load_model(model_save_path)

# Load the label_to_index dictionary
label_to_index_save_path = r"C:\\Users\\thath\\OneDrive - University of Bradford\\Discipline-specific Artificial Intelligence Project\\Project file\\Test 02\\Testing code\\label_to_index.pkl"
with open(label_to_index_save_path, 'rb') as f:
    label_to_index = pickle.load(f)

# Create a reverse mapping from index to label
index_to_label = {index: label for label, index in label_to_index.items()}

# Define colors for each category
category_colors = {
    "AnnualCrop": (255, 255, 0, 128),  # Yellow with transparency
    "Forest": (0, 128, 0, 128),  # Green with transparency
    "HerbaceousVegetation": (144, 238, 144, 128),  # Light Green with transparency
    "Industrial": (255, 165, 0, 128),  # Orange with transparency
    "Pasture": (173, 216, 230, 128),  # Light Blue with transparency
    "PermanentCrop": (0, 100, 0, 128),  # Dark Green with transparency
    "Residential": (255, 0, 0, 128),  # Red with transparency
    "River": (0, 0, 255, 128),  # Blue with transparency
    "SeaLake": (0, 255, 255, 128)  # Cyan with transparency
}

# Preprocess the input image
def preprocess_image(image):
    img = image.resize((64, 64))  # Resize image to match the input size of the model
    img_array = np.array(img) / 255.0  # Normalize image
    img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension
    return img_array

# Process the larger image and highlight the smaller images
def process_large_image(image_path):
    original_image = Image.open(image_path).convert('RGB')  # Ensure image is in RGB mode
    width, height = original_image.size
    final_image = original_image.copy()
    draw = ImageDraw.Draw(final_image, 'RGBA')

    for i in range(0, width, 64):
        for j in range(0, height, 64):
            box = (i, j, i + 64, j + 64)
            cropped_image = original_image.crop(box)
            preprocessed_image = preprocess_image(cropped_image)
            predictions = model.predict(preprocessed_image)
            predicted_class = np.argmax(predictions, axis=1)[0]
            predicted_label = index_to_label[predicted_class]

            # Debugging: Print the predicted label and corresponding color
            color = category_colors.get(predicted_label, (255, 255, 255, 128))  # Default to semi-transparent white if category not found
            print(f"Box {box}: {predicted_label}, Color: {color}")

            # Highlight the image according to its category
            draw.rectangle(box, fill=color)

    return final_image

# Display the final image
image_path = r"C:\\Users\\thath\\OneDrive - University of Bradford\\Discipline-specific Artificial Intelligence Project\\Test sampel\\Screenshot 2025-03-14 160213.jpg"
final_image = process_large_image(image_path)
final_image.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 518ms/step
# Box (0, 0, 64, 64): PermanentCrop, Color: (0, 100, 0, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# Box (0, 64, 64, 128): HerbaceousVegetation, Color: (144, 238, 144, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# Box (0, 128, 64, 192): PermanentCrop, Color: (0, 100, 0, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# Box (0, 192, 64, 256): PermanentCrop, Color: (0, 100, 0, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# Box (0, 256, 64, 320): PermanentCrop, Color: (0, 100, 0, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# Box (0, 320, 64, 384): HerbaceousVegetation, Color: (144, 238, 144, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# Box (0, 384, 64, 448): PermanentCrop, Color: (0, 100, 0, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# Box (0, 448, 64, 512): PermanentCrop, Color: (0, 100, 0, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# Box (0, 512, 64, 576): HerbaceousVegetation, Color: (144, 238, 144, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# Box (0, 576, 64, 640): Industrial, Color: (255, 165, 0, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Box (64, 0, 128, 64): HerbaceousVegetation, Color: (144, 238, 144, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# Box (64, 64, 128, 128): Industrial, Color: (255, 165, 0, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# Box (64, 128, 128, 192): PermanentCrop, Color: (0, 100, 0, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# Box (64, 192, 128, 256): HerbaceousVegetation, Color: (144, 238, 144, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Box (64, 256, 128, 320): PermanentCrop, Color: (0, 100, 0, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# Box (64, 320, 128, 384): PermanentCrop, Color: (0, 100, 0, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# Box (64, 384, 128, 448): HerbaceousVegetation, Color: (144, 238, 144, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Box (64, 448, 128, 512): HerbaceousVegetation, Color: (144, 238, 144, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# Box (64, 512, 128, 576): HerbaceousVegetation, Color: (144, 238, 144, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Box (64, 576, 128, 640): Industrial, Color: (255, 165, 0, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# Box (128, 0, 192, 64): PermanentCrop, Color: (0, 100, 0, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Box (128, 64, 192, 128): Industrial, Color: (255, 165, 0, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Box (128, 128, 192, 192): PermanentCrop, Color: (0, 100, 0, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Box (128, 192, 192, 256): HerbaceousVegetation, Color: (144, 238, 144, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# Box (128, 256, 192, 320): HerbaceousVegetation, Color: (144, 238, 144, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# Box (128, 320, 192, 384): PermanentCrop, Color: (0, 100, 0, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# Box (128, 384, 192, 448): HerbaceousVegetation, Color: (144, 238, 144, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# Box (128, 448, 192, 512): PermanentCrop, Color: (0, 100, 0, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Box (128, 512, 192, 576): PermanentCrop, Color: (0, 100, 0, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Box (128, 576, 192, 640): Pasture, Color: (173, 216, 230, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# Box (192, 0, 256, 64): HerbaceousVegetation, Color: (144, 238, 144, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# Box (192, 64, 256, 128): Industrial, Color: (255, 165, 0, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# Box (192, 128, 256, 192): Industrial, Color: (255, 165, 0, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Box (192, 192, 256, 256): Pasture, Color: (173, 216, 230, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# Box (192, 256, 256, 320): HerbaceousVegetation, Color: (144, 238, 144, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Box (192, 320, 256, 384): HerbaceousVegetation, Color: (144, 238, 144, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# Box (192, 384, 256, 448): HerbaceousVegetation, Color: (144, 238, 144, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# Box (192, 448, 256, 512): PermanentCrop, Color: (0, 100, 0, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Box (192, 512, 256, 576): HerbaceousVegetation, Color: (144, 238, 144, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# Box (192, 576, 256, 640): Pasture, Color: (173, 216, 230, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# Box (256, 0, 320, 64): Industrial, Color: (255, 165, 0, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# Box (256, 64, 320, 128): Industrial, Color: (255, 165, 0, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# Box (256, 128, 320, 192): HerbaceousVegetation, Color: (144, 238, 144, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Box (256, 192, 320, 256): Residential, Color: (255, 0, 0, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Box (256, 256, 320, 320): PermanentCrop, Color: (0, 100, 0, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Box (256, 320, 320, 384): HerbaceousVegetation, Color: (144, 238, 144, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# Box (256, 384, 320, 448): HerbaceousVegetation, Color: (144, 238, 144, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# Box (256, 448, 320, 512): PermanentCrop, Color: (0, 100, 0, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Box (256, 512, 320, 576): HerbaceousVegetation, Color: (144, 238, 144, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# Box (256, 576, 320, 640): Pasture, Color: (173, 216, 230, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Box (320, 0, 384, 64): PermanentCrop, Color: (0, 100, 0, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# Box (320, 64, 384, 128): HerbaceousVegetation, Color: (144, 238, 144, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# Box (320, 128, 384, 192): HerbaceousVegetation, Color: (144, 238, 144, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Box (320, 192, 384, 256): PermanentCrop, Color: (0, 100, 0, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Box (320, 256, 384, 320): PermanentCrop, Color: (0, 100, 0, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# Box (320, 320, 384, 384): PermanentCrop, Color: (0, 100, 0, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# Box (320, 384, 384, 448): PermanentCrop, Color: (0, 100, 0, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# Box (320, 448, 384, 512): HerbaceousVegetation, Color: (144, 238, 144, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# Box (320, 512, 384, 576): HerbaceousVegetation, Color: (144, 238, 144, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Box (320, 576, 384, 640): PermanentCrop, Color: (0, 100, 0, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# Box (384, 0, 448, 64): HerbaceousVegetation, Color: (144, 238, 144, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Box (384, 64, 448, 128): HerbaceousVegetation, Color: (144, 238, 144, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# Box (384, 128, 448, 192): HerbaceousVegetation, Color: (144, 238, 144, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# Box (384, 192, 448, 256): HerbaceousVegetation, Color: (144, 238, 144, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# Box (384, 256, 448, 320): HerbaceousVegetation, Color: (144, 238, 144, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# Box (384, 320, 448, 384): HerbaceousVegetation, Color: (144, 238, 144, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Box (384, 384, 448, 448): Pasture, Color: (173, 216, 230, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# Box (384, 448, 448, 512): Pasture, Color: (173, 216, 230, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# Box (384, 512, 448, 576): HerbaceousVegetation, Color: (144, 238, 144, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# Box (384, 576, 448, 640): Pasture, Color: (173, 216, 230, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# Box (448, 0, 512, 64): HerbaceousVegetation, Color: (144, 238, 144, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# Box (448, 64, 512, 128): Pasture, Color: (173, 216, 230, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# Box (448, 128, 512, 192): HerbaceousVegetation, Color: (144, 238, 144, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# Box (448, 192, 512, 256): HerbaceousVegetation, Color: (144, 238, 144, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# Box (448, 256, 512, 320): Pasture, Color: (173, 216, 230, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# Box (448, 320, 512, 384): Pasture, Color: (173, 216, 230, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# Box (448, 384, 512, 448): Pasture, Color: (173, 216, 230, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Box (448, 448, 512, 512): Forest, Color: (0, 128, 0, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# Box (448, 512, 512, 576): Pasture, Color: (173, 216, 230, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# Box (448, 576, 512, 640): Pasture, Color: (173, 216, 230, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# Box (512, 0, 576, 64): Pasture, Color: (173, 216, 230, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# Box (512, 64, 576, 128): HerbaceousVegetation, Color: (144, 238, 144, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# Box (512, 128, 576, 192): HerbaceousVegetation, Color: (144, 238, 144, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# Box (512, 192, 576, 256): Pasture, Color: (173, 216, 230, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# Box (512, 256, 576, 320): Pasture, Color: (173, 216, 230, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# Box (512, 320, 576, 384): Pasture, Color: (173, 216, 230, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# Box (512, 384, 576, 448): Forest, Color: (0, 128, 0, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# Box (512, 448, 576, 512): Forest, Color: (0, 128, 0, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# Box (512, 512, 576, 576): Pasture, Color: (173, 216, 230, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# Box (512, 576, 576, 640): Pasture, Color: (173, 216, 230, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# Box (576, 0, 640, 64): Forest, Color: (0, 128, 0, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Box (576, 64, 640, 128): Pasture, Color: (173, 216, 230, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Box (576, 128, 640, 192): HerbaceousVegetation, Color: (144, 238, 144, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# Box (576, 192, 640, 256): Pasture, Color: (173, 216, 230, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# Box (576, 256, 640, 320): Forest, Color: (0, 128, 0, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Box (576, 320, 640, 384): Pasture, Color: (173, 216, 230, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Box (576, 384, 640, 448): Forest, Color: (0, 128, 0, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Box (576, 448, 640, 512): Forest, Color: (0, 128, 0, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# Box (576, 512, 640, 576): HerbaceousVegetation, Color: (144, 238, 144, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Box (576, 576, 640, 640): Pasture, Color: (173, 216, 230, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# Box (640, 0, 704, 64): Pasture, Color: (173, 216, 230, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Box (640, 64, 704, 128): Forest, Color: (0, 128, 0, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# Box (640, 128, 704, 192): Pasture, Color: (173, 216, 230, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Box (640, 192, 704, 256): Pasture, Color: (173, 216, 230, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Box (640, 256, 704, 320): Pasture, Color: (173, 216, 230, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# Box (640, 320, 704, 384): Forest, Color: (0, 128, 0, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# Box (640, 384, 704, 448): Forest, Color: (0, 128, 0, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Box (640, 448, 704, 512): Forest, Color: (0, 128, 0, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Box (640, 512, 704, 576): Forest, Color: (0, 128, 0, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# Box (640, 576, 704, 640): Pasture, Color: (173, 216, 230, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# Box (704, 0, 768, 64): HerbaceousVegetation, Color: (144, 238, 144, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# Box (704, 64, 768, 128): Forest, Color: (0, 128, 0, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# Box (704, 128, 768, 192): Pasture, Color: (173, 216, 230, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# Box (704, 192, 768, 256): Forest, Color: (0, 128, 0, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Box (704, 256, 768, 320): Forest, Color: (0, 128, 0, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# Box (704, 320, 768, 384): HerbaceousVegetation, Color: (144, 238, 144, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# Box (704, 384, 768, 448): HerbaceousVegetation, Color: (144, 238, 144, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# Box (704, 448, 768, 512): HerbaceousVegetation, Color: (144, 238, 144, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# Box (704, 512, 768, 576): Forest, Color: (0, 128, 0, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# Box (704, 576, 768, 640): Pasture, Color: (173, 216, 230, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# Box (768, 0, 832, 64): Forest, Color: (0, 128, 0, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Box (768, 64, 832, 128): Forest, Color: (0, 128, 0, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# Box (768, 128, 832, 192): Forest, Color: (0, 128, 0, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Box (768, 192, 832, 256): Forest, Color: (0, 128, 0, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# Box (768, 256, 832, 320): Pasture, Color: (173, 216, 230, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# Box (768, 320, 832, 384): Forest, Color: (0, 128, 0, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# Box (768, 384, 832, 448): Pasture, Color: (173, 216, 230, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# Box (768, 448, 832, 512): Pasture, Color: (173, 216, 230, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Box (768, 512, 832, 576): Pasture, Color: (173, 216, 230, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# Box (768, 576, 832, 640): Pasture, Color: (173, 216, 230, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# Box (832, 0, 896, 64): Forest, Color: (0, 128, 0, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# Box (832, 64, 896, 128): Forest, Color: (0, 128, 0, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Box (832, 128, 896, 192): Forest, Color: (0, 128, 0, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# Box (832, 192, 896, 256): Forest, Color: (0, 128, 0, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# Box (832, 256, 896, 320): Pasture, Color: (173, 216, 230, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# Box (832, 320, 896, 384): Forest, Color: (0, 128, 0, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# Box (832, 384, 896, 448): Forest, Color: (0, 128, 0, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# Box (832, 448, 896, 512): Forest, Color: (0, 128, 0, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# Box (832, 512, 896, 576): Pasture, Color: (173, 216, 230, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# Box (832, 576, 896, 640): Pasture, Color: (173, 216, 230, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# Box (896, 0, 960, 64): Pasture, Color: (173, 216, 230, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# Box (896, 64, 960, 128): Pasture, Color: (173, 216, 230, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Box (896, 128, 960, 192): Pasture, Color: (173, 216, 230, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Box (896, 192, 960, 256): Pasture, Color: (173, 216, 230, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Box (896, 256, 960, 320): Pasture, Color: (173, 216, 230, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# Box (896, 320, 960, 384): Pasture, Color: (173, 216, 230, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Box (896, 384, 960, 448): Pasture, Color: (173, 216, 230, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# Box (896, 448, 960, 512): Pasture, Color: (173, 216, 230, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# Box (896, 512, 960, 576): Pasture, Color: (173, 216, 230, 128)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Box (896, 576, 960, 640): River, Color: (0, 0, 255, 128)
